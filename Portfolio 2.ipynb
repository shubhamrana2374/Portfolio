# %% [markdown]
# # Portfolio 2
#
# __Data driven prediction models of energy use of appliances in a low-energy house.__

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import r2_score
import matplotlib.pyplot as plotter
from datetime import datetime
import calendar
from matplotlib import pyplot as plt
from datetime import timedelta
import seaborn as sns
import matplotlib.pylab as plt
# %matplotlib inline

# %% [markdown]
# # Loading Data
#
# The first dataset is the complete data which consists all data of the energy consumption. Then we have two more datasets training and testing datasets which are the subset of the complete data. We wil train a certain set of data and test on other data to check the correctness of the model developed.

# %%
#Reading complete csv
complete_data = pd.read_csv('data/energydata_complete.csv',parse_dates=True)
complete_data['date']=complete_data['date'].astype(str)
#complete_data['date'] =[datetime.strptime(x, '%Y%m%d') for x in complete_data['date']]
complete_data.head()
# Out:
#        date  Appliances  lights     T1       RH_1    T2       RH_2     T3  \
# 0  20160111          60      30  19.89  47.596667  19.2  44.790000  19.79
# 1  20160111          60      30  19.89  46.693333  19.2  44.722500  19.79
# 2  20160111          50      30  19.89  46.300000  19.2  44.626667  19.79
# 3  20160111          50      40  19.89  46.066667  19.2  44.590000  19.79
# 4  20160111          60      40  19.89  46.333333  19.2  44.530000  19.79
#
#         RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5    92.0
# 1  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6    92.0
# 2  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7    92.0
# 3  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8    92.0
# 4  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9    92.0
#
#    Windspeed  Visibility  Tdewpoint        rv1        rv2
# 0   7.000000   63.000000        5.3  13.275433  13.275433
# 1   6.666667   59.166667        5.2  18.606195  18.606195
# 2   6.333333   55.333333        5.1  28.642668  28.642668
# 3   6.000000   51.500000        5.0  45.410389  45.410389
# 4   5.666667   47.666667        4.9  10.084097  10.084097
#
# [5 rows x 29 columns]

# %% [markdown]
# # Intrepretation
#
# Complete dataset is divided into training and testing data to perform analysis.

# %%
#Reading testing data
test_data = pd.read_csv('data/energydata_testing.csv', index_col='date', parse_dates=True)
test_data.head()
# Out:
#                      Appliances  lights         T1       RH_1         T2  \
# date
# 2016-01-11 17:30:00          50      40  19.890000  46.066667  19.200000
# 2016-01-11 18:00:00          60      50  19.890000  45.766667  19.200000
# 2016-01-11 18:40:00         230      70  19.926667  45.863333  19.356667
# 2016-01-11 18:50:00         580      60  20.066667  46.396667  19.426667
# 2016-01-11 19:30:00         100      10  20.566667  53.893333  20.033333
#
#                           RH_2     T3       RH_3     T4       RH_4  ...  \
# date                                                                ...
# 2016-01-11 17:30:00  44.590000  19.79  45.000000  18.89  45.723333  ...
# 2016-01-11 18:00:00  44.500000  19.79  44.900000  18.89  45.790000  ...
# 2016-01-11 18:40:00  44.400000  19.79  44.900000  18.89  46.430000  ...
# 2016-01-11 18:50:00  44.400000  19.79  44.826667  19.00  46.430000  ...
# 2016-01-11 19:30:00  46.756667  20.10  48.466667  19.00  48.490000  ...
#
#                      Press_mm_hg     RH_out  Windspeed  Visibility  Tdewpoint  \
# date
# 2016-01-11 17:30:00   733.800000  92.000000   6.000000        51.5   5.000000
# 2016-01-11 18:00:00   734.100000  92.000000   5.000000        40.0   4.700000
# 2016-01-11 18:40:00   734.366667  91.333333   5.666667        40.0   4.633333
# 2016-01-11 18:50:00   734.433333  91.166667   5.833333        40.0   4.616667
# 2016-01-11 19:30:00   734.850000  89.500000   6.000000        40.0   4.350000
#
#                            rv1        rv2    NSM  WeekStatus  Day_of_week
# date
# 2016-01-11 17:30:00  45.410389  45.410389  63000     Weekday       Monday
# 2016-01-11 18:00:00  47.233763  47.233763  64800     Weekday       Monday
# 2016-01-11 18:40:00  10.298729  10.298729  67200     Weekday       Monday
# 2016-01-11 18:50:00   8.827838   8.827838  67800     Weekday       Monday
# 2016-01-11 19:30:00  24.884962  24.884962  70200     Weekday       Monday
#
# [5 rows x 31 columns]

# %%
#Reading training data
train_data = pd.read_csv('data/energydata_training.csv', index_col='date', parse_dates=True)
train_data.head()
# Out:
#                      Appliances  lights     T1       RH_1    T2       RH_2  \
# date
# 2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
# 2016-01-11 17:50:00          50      40  19.89  46.026667  19.2  44.500000
#
#                         T3       RH_3         T4       RH_4  ...  Press_mm_hg  \
# date                                                         ...
# 2016-01-11 17:00:00  19.79  44.730000  19.000000  45.566667  ...        733.5
# 2016-01-11 17:10:00  19.79  44.790000  19.000000  45.992500  ...        733.6
# 2016-01-11 17:20:00  19.79  44.933333  18.926667  45.890000  ...        733.7
# 2016-01-11 17:40:00  19.79  45.000000  18.890000  45.530000  ...        733.9
# 2016-01-11 17:50:00  19.79  44.933333  18.890000  45.730000  ...        734.0
#
#                      RH_out  Windspeed  Visibility  Tdewpoint        rv1  \
# date
# 2016-01-11 17:00:00    92.0   7.000000   63.000000        5.3  13.275433
# 2016-01-11 17:10:00    92.0   6.666667   59.166667        5.2  18.606195
# 2016-01-11 17:20:00    92.0   6.333333   55.333333        5.1  28.642668
# 2016-01-11 17:40:00    92.0   5.666667   47.666667        4.9  10.084097
# 2016-01-11 17:50:00    92.0   5.333333   43.833333        4.8  44.919484
#
#                            rv2    NSM  WeekStatus  Day_of_week
# date
# 2016-01-11 17:00:00  13.275433  61200     Weekday       Monday
# 2016-01-11 17:10:00  18.606195  61800     Weekday       Monday
# 2016-01-11 17:20:00  28.642668  62400     Weekday       Monday
# 2016-01-11 17:40:00  10.084097  63600     Weekday       Monday
# 2016-01-11 17:50:00  44.919484  64200     Weekday       Monday
#
# [5 rows x 31 columns]

# %%
date_appliances_data=complete_data[["date","Appliances"]]

#whole data 
date_appliances_data.plot(kind='line',x='date', y='Appliances')

#1st week data
date_appliances_data[1:1008].plot(kind='line',x='date', y='Appliances')

# %% [markdown]
# # Intrepretation
# There are two line graphs plotted, one is depicting the whole data between appliances and date. Whereas, second graph illustrates one week usage of appliances. Highest amount of energy consumed between 15th and 16th of January.

# %%
#date_appliances_data1=date_appliances_data["Appliances"]
date_appliances_data['Appliances'].plot.hist(bins=40) 
plt.subplots_adjust(right=3)
plt.xlim([0,1200])
plt.xlabel("Appliances Wh")
plt.ylim(0,9000,2000)
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
ax = sns.boxplot(x=date_appliances_data["Appliances"])
plt.xlabel("Appliances Wh")
plt.subplots_adjust(right=3)
plt.show()

# %%
train_data_corr =train_data [["Appliances", "lights","T1","RH_1","T2","RH_2","T3","RH_3"]]
sns.pairplot(train_data_corr,diag_kind = 'kde',plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %%
train_data_corr1=train_data_corr.corr()
def color_negative_red(value):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if value < 0 else 'black'
    return 'color: %s' % color

train_data_corr1.style.applymap(color_negative_red)

# negative values are highlighted
# Out:
# <style  type="text/css" >
#     #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow0_col0 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow0_col1 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow0_col2 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow0_col3 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow0_col4 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow0_col5 {
#             color:  red;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow0_col6 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow0_col7 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow1_col0 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow1_col1 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow1_col2 {
#             color:  red;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow1_col3 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow1_col4 {
#             color:  red;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow1_col5 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow1_col6 {
#             color:  red;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow1_col7 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow2_col0 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow2_col1 {
#             color:  red;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow2_col2 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow2_col3 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow2_col4 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow2_col5 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow2_col6 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow2_col7 {
#             color:  red;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow3_col0 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow3_col1 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow3_col2 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow3_col3 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow3_col4 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow3_col5 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow3_col6 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow3_col7 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow4_col0 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow4_col1 {
#             color:  red;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow4_col2 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow4_col3 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow4_col4 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow4_col5 {
#             color:  red;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow4_col6 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow4_col7 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow5_col0 {
#             color:  red;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow5_col1 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow5_col2 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow5_col3 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow5_col4 {
#             color:  red;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow5_col5 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow5_col6 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow5_col7 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow6_col0 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow6_col1 {
#             color:  red;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow6_col2 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow6_col3 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow6_col4 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow6_col5 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow6_col6 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow6_col7 {
#             color:  red;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow7_col0 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow7_col1 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow7_col2 {
#             color:  red;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow7_col3 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow7_col4 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow7_col5 {
#             color:  black;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow7_col6 {
#             color:  red;
#         }    #T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow7_col7 {
#             color:  black;
#         }</style><table id="T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Appliances</th>        <th class="col_heading level0 col1" >lights</th>        <th class="col_heading level0 col2" >T1</th>        <th class="col_heading level0 col3" >RH_1</th>        <th class="col_heading level0 col4" >T2</th>        <th class="col_heading level0 col5" >RH_2</th>        <th class="col_heading level0 col6" >T3</th>        <th class="col_heading level0 col7" >RH_3</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7dlevel0_row0" class="row_heading level0 row0" >Appliances</th>
#                         <td id="T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow0_col1" class="data row0 col1" >0.194689</td>
#                         <td id="T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow0_col2" class="data row0 col2" >0.0601368</td>
#                         <td id="T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow0_col3" class="data row0 col3" >0.0872764</td>
#                         <td id="T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow0_col4" class="data row0 col4" >0.124719</td>
#                         <td id="T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow0_col5" class="data row0 col5" >-0.0611083</td>
#                         <td id="T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow0_col6" class="data row0 col6" >0.0933363</td>
#                         <td id="T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow0_col7" class="data row0 col7" >0.0367649</td>
#             </tr>
#             <tr>
#                         <th id="T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7dlevel0_row1" class="row_heading level0 row1" >lights</th>
#                         <td id="T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow1_col0" class="data row1 col0" >0.194689</td>
#                         <td id="T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow1_col1" class="data row1 col1" >1</td>
#                         <td id="T_0febdf50_d4ff_11e9_b92f_3ca82aae2d7drow1_col2" class="data row1 col2" >-0

# %% [markdown]
# # Intrepretation
#
# Pairplot shows the correlation between various variables and to make it more understandable , correlation values are also calculated. This shows negative values in the red and other are in black. Red value means low correlation and black one depicts strong corelation.
